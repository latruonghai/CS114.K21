# %% [markdown]
# <a href="https://colab.research.google.com/github/latruonghai/CS114.K21/blob/master/BTH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a777fb1f-a05a-43a9-be3b-5e70a502dfe0" name="files[]" multiple disabled />
#      <output id="result-a777fb1f-a05a-43a9-be3b-5e70a502dfe0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv
# ...

# %%
import pandas as pd

dataset = pd.read_csv("data.csv")

# %%
dataset.describe()
x = dataset['O(N)']
y = dataset.Time
# Out:
# 0       4032139
# 1       2055486
# 2       5626651
# 3         42065
# 4       6297788
#          ...
# 5206    6600098
# 5207    5339132
# 5208    4794647
# 5209    4440131
# 5210    2033708
# Name: O(N), Length: 5211, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.plot(x,y,'go')
plt.show()

# %% [markdown]
# Tạo dữ liệu train và test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, Y_train, Y_test = train_test_split(x,y,test_size = 0.2, random_state=0)

# %%
X_train = X_train.values.reshape(-1,1)
Y_train = Y_train.values.reshape(-1,1)
X_test = X_test.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

LR = LinearRegression()
LR.fit(X_train, Y_train)
model_train = LR.predict(X_test)
print(model_train)
print(Y_test)
# Out:
# [[0.22613503]
#  [2.28558382]
#  [0.80778399]
#  ...
#  [0.63113466]
#  [1.08448996]
#  [0.67774893]]
# 1398    0.235252
# 4773    2.327880
# 2243    0.803234
# 1139    2.189050
# 1203    0.120225
#           ...
# 2836    2.504730
# 1933    0.591281
# 2849    0.619440
# 1833    1.059560
# 1754    0.680740
# Name: Time, Length: 1043, dtype: float64

# %% [markdown]
# Biểu diễn model lên đồ thị

# %%
plt.plot(X_train,Y_train,'.',X_test,model_train,'-')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(Y_test,model_train))
# Out:
# 0.001962179107072886
